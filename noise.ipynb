# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.arange(0, 2*np.pi, 0.01)
Y = np.cos(X)

# %%
plt.figure()
plt.plot(X, Y)
plt.show()

# %%
noise = np.random.normal(0, 0.05, len(X))
Yn = Y + noise

plt.figure()
plt.plot(X, Yn)
plt.show()
